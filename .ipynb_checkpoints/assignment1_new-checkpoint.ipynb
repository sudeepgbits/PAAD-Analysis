# %%
import cmapPy

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from cmapPy.pandasGEXpress import gctx2gct
from cmapPy.pandasGEXpress.parse import parse
from cmapPy.pandasGEXpress import subset as subset

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
data = parse("Copy of PAAD.gct",convert_neg_666=True,make_multiindex=True)

# %%
print(data)
# Out:
# GCT1.3
# src: Copy of PAAD.gct
# data_df: [18465 rows x 183 columns]
# row_metadata_df: [18465 rows x 0 columns]
# col_metadata_df: [183 rows x 124 columns]

# %%
mydata = data.data_df

# %%
rows,cols = mydata.shape

# %%
mydata.head()
# Out:
# cid    aab1-Primary solid Tumor  aab4-Primary solid Tumor  \
# rid
# A1BG                        6.4                       5.8
# A1CF                        4.7                       5.7
# A2BP1                      -1.0                       1.1
# A2LD1                       7.5                       6.8
# A2ML1                       6.4                       NaN
#
# cid    aab6-Primary solid Tumor  aab8-Primary solid Tumor  \
# rid
# A1BG                        6.4                       5.8
# A1CF                        3.0                       5.1
# A2BP1                       NaN                       NaN
# A2LD1                       7.3                       7.5
# A2ML1                      10.8                       4.1
#
# cid    aab9-Primary solid Tumor  aaba-Primary solid Tumor  \
# rid
# A1BG                        6.7                       6.6
# A1CF                        4.4                       4.2
# A2BP1                       0.1                       NaN
# A2LD1                       7.4                       6.6
# A2ML1                       9.3                       9.8
#
# cid    aabe-Primary solid Tumor  aabf-Primary solid Tumor  \
# rid
# A1BG                        6.3                       6.5
# A1CF                        1.6                       6.8
# A2BP1                       NaN                       1.7
# A2LD1                       7.1                       6.8
# A2ML1                       6.2                       3.8
#
# cid    aabh-Primary solid Tumor  aabi-Primary solid Tumor  ...  \
# rid                                                        ...
# A1BG                        5.7                       6.3  ...
# A1CF                        6.0                       NaN  ...
# A2BP1                       0.4                      -1.5  ...
# A2LD1                       8.0                       5.8  ...
# A2ML1                       2.3                      10.1  ...
#
# cid    aauh-Primary solid Tumor  aaui-Primary solid Tumor  \
# rid
# A1BG                        7.1                       7.1
# A1CF                        5.4                       6.4
# A2BP1                       3.5                       1.3
# A2LD1                       6.5                       7.3
# A2ML1                       0.1                       3.4
#
# cid    aaul-Primary solid Tumor  a8t3-Primary solid Tumor  \
# rid
# A1BG                        6.7                       7.0
# A1CF                        6.5                       4.4
# A2BP1                      -0.3                       NaN
# A2LD1                       6.1                       6.7
# A2ML1                       3.7                      -0.9
#
# cid    a8t5-Primary solid Tumor  a89d-Solid Tissue Normal  \
# rid
# A1BG                        6.9                       7.1
# A1CF                        3.3                       3.6
# A2BP1                       2.1                       2.0
# A2LD1                       6.5                       6.7
# A2ML1                       3.6                       1.0
#
# cid    a89d-Primary solid Tumor  a8sy-Primary solid Tumor  \
# rid
# A1BG                        7.3                       7.9
# A1CF                        6.2                       1.2
# A2BP1                       0.0                       NaN
# A2LD1                       6.7                       6.5
# A2ML1                       2.8                      10.5
#
# cid    a8lh-Primary solid Tumor  aapl-Primary solid Tumor
# rid
# A1BG                        6.0                       6.9
# A1CF                        4.9                       2.0
# A2BP1                       2.0                       NaN
# A2LD1                       6.9                       6.7
# A2ML1                       3.1                       5.1
#
# [5 rows x 183 columns]

# %%
df_data = data.data_df.dropna()
df_row = data.row_metadata_df
df_col = data.col_metadata_df

# %%
df_data.head()
# Out:
# cid     aab1-Primary solid Tumor  aab4-Primary solid Tumor  \
# rid
# A1BG                         6.4                       5.8
# A2LD1                        7.5                       6.8
# A2M                         14.3                      14.0
# A4GALT                      10.6                      10.2
# AAAS                         9.4                       9.1
#
# cid     aab6-Primary solid Tumor  aab8-Primary solid Tumor  \
# rid
# A1BG                         6.4                       5.8
# A2LD1                        7.3                       7.5
# A2M                         13.1                      13.8
# A4GALT                      10.1                       8.6
# AAAS                         9.7                       9.6
#
# cid     aab9-Primary solid Tumor  aaba-Primary solid Tumor  \
# rid
# A1BG                         6.7                       6.6
# A2LD1                        7.4                       6.6
# A2M                         14.6                      13.3
# A4GALT                      10.1                       9.3
# AAAS                         9.8                       9.3
#
# cid     aabe-Primary solid Tumor  aabf-Primary solid Tumor  \
# rid
# A1BG                         6.3                       6.5
# A2LD1                        7.1                       6.8
# A2M                         13.4                      14.2
# A4GALT                       9.5                       8.4
# AAAS                         9.5                       9.3
#
# cid     aabh-Primary solid Tumor  aabi-Primary solid Tumor  ...  \
# rid                                                         ...
# A1BG                         5.7                       6.3  ...
# A2LD1                        8.0                       5.8  ...
# A2M                         13.9                      11.9  ...
# A4GALT                       8.4                       7.9  ...
# AAAS                         9.0                       9.3  ...
#
# cid     aauh-Primary solid Tumor  aaui-Primary solid Tumor  \
# rid
# A1BG                         7.1                       7.1
# A2LD1                        6.5                       7.3
# A2M                         14.5                      14.3
# A4GALT                       9.1                       9.5
# AAAS                         9.2                       9.4
#
# cid     aaul-Primary solid Tumor  a8t3-Primary solid Tumor  \
# rid
# A1BG                         6.7                       7.0
# A2LD1                        6.1                       6.7
# A2M                         14.5                      14.2
# A4GALT                      10.0                       9.5
# AAAS                         9.3                       9.5
#
# cid     a8t5-Primary solid Tumor  a89d-Solid Tissue Normal  \
# rid
# A1BG                         6.9                       7.1
# A2LD1                        6.5                       6.7
# A2M                         14.3                      14.9
# A4GALT                       9.1                      10.5
# AAAS                         9.0                       9.2
#
# cid     a89d-Primary solid Tumor  a8sy-Primary solid Tumor  \
# rid
# A1BG                         7.3                       7.9
# A2LD1                        6.7                       6.5
# A2M                         14.5                      13.0
# A4GALT                       9.8                      10.8
# AAAS                         9.2                       9.3
#
# cid     a8lh-Primary solid Tumor  aapl-Primary solid Tumor
# rid
# A1BG                         6.0                       6.9
# A2LD1                        6.9                       6.7
# A2M                         12.1                      13.3
# A4GALT                       8.3                       9.0
# AAAS                         9.6                       9.6
#
# [5 rows x 183 columns]

# %%
fil_rows, fil_cols = df_data.shape

# %% [markdown]
# ## Rows with NaN

# %%
print("rows with NaN = {}".format(rows-fil_rows))
# Out:
# rows with NaN = 4367

# %%
#list(df_data.head(0))

# %%
#a = df_data.T
cols = df_data.head(0)
cols = list(cols)
#print(cols)

# %% [markdown]
# ## Box Plot

# %%
myFig = plt.figure(figsize=(25, 12));
#data.head()
boxplot = df_data.boxplot(column=cols,rot = 90)
plt.show()
#for i in range(50,201,50):
#    if i == 200:
#        #print("i = 200")
#        i = 183
#    boxplot = a.boxplot(column=cols[d:i],rot = 90)
#    myFig.savefig("boxplot {}.png".format(i),bbox_inches = "tight")
#    d = i + 1

# %% [markdown]
# ## PCA Plot

# %%
cols = df_data.head(0)
cols = (list(cols))
x = df_data.loc[:, cols].values
x = StandardScaler().fit_transform(x)
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x.T)
fig = plt.figure()
plt.scatter(principalComponents[:, 0], principalComponents[:, 1],
            edgecolor='none', alpha=0.5)
plt.xlabel('component 1')
plt.ylabel('component 2')
fig.savefig("PCA plot 1.png")

# %%
pca.explained_variance_
# Out:
# array([297.41385, 269.7709 ], dtype=float32)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.15838031, 0.14365976], dtype=float32)

# %%
principalDf = pd.DataFrame(data = principalComponents)

# %%
import numpy as np
arrr = np.reshape(df_col["histological_type_other"].values,(len(df_col["histological_type_other"].values),1))

# %%
df2 = pd.DataFrame(arrr)

# %%
finalDf = pd.concat([principalDf, df2], axis = 1)

# %%
finalDf.head()
finalDf.columns = ['principal component 1', 'principal component 2','target']
finalDf.head()
# Out:
#    principal component 1  principal component 2                         target
# 0             -10.684379              -5.995140        invasive adenocarcinoma
# 1              -6.519267              -3.531364  invasive, well-differentiated
# 2              -7.748507              -2.708203                            NaN
# 3              -8.714307             -11.086410                            NaN
# 4               4.894306              -3.071834                            NaN

# %%
my_data_t = df_data.T

# %%
my_data_t.head()
# Out:
# rid                       A1BG  A2LD1   A2M  A4GALT  AAAS  AACS  AADAT  AAGAB  \
# cid
# aab1-Primary solid Tumor   6.4    7.5  14.3    10.6   9.4  10.2    4.8   10.2
# aab4-Primary solid Tumor   5.8    6.8  14.0    10.2   9.1  10.3    6.3   10.4
# aab6-Primary solid Tumor   6.4    7.3  13.1    10.1   9.7   9.2    5.9    9.9
# aab8-Primary solid Tumor   5.8    7.5  13.8     8.6   9.6   9.4    6.4   10.5
# aab9-Primary solid Tumor   6.7    7.4  14.6    10.1   9.8   9.3    6.5   10.1
#
# rid                       AAK1  AAMP  ...  ZW10  ZWILCH  ZWINT  ZXDA  ZXDB  \
# cid                                   ...
# aab1-Primary solid Tumor   9.6  11.8  ...   8.6     8.1    8.6   6.2   9.0
# aab4-Primary solid Tumor   9.8  11.4  ...   8.7     8.1    8.8   5.8   8.5
# aab6-Primary solid Tumor   9.8  11.1  ...   8.8     8.4    9.1   3.9   8.1
# aab8-Primary solid Tumor   9.2  11.6  ...   8.6     8.6    8.9   5.2   8.5
# aab9-Primary solid Tumor   9.8  11.2  ...   8.9     8.2    8.4   5.9   8.6
#
# rid                       ZXDC  ZYG11B   ZYX  ZZEF1  ZZZ3
# cid
# aab1-Primary solid Tumor   9.9     9.2  12.9   10.1   9.3
# aab4-Primary solid Tumor  10.0     9.3  12.4    9.8   8.9
# aab6-Primary solid Tumor  10.0     9.4  13.5    9.8   9.2
# aab8-Primary solid Tumor   9.7     9.4  12.5    9.7   9.3
# aab9-Primary solid Tumor   9.9     9.3  13.0   10.1   9.2
#
# [5 rows x 14098 columns]

# %%
my_data_t.shape
# Out:
# (183, 14098)

# %%
#df_col["histological_type_other"]

# %%
df_new = my_data_t.join(df_col["histological_type_other"])

# %%
df_new.head()
# Out:
#                           A1BG  A2LD1   A2M  A4GALT  AAAS  AACS  AADAT  AAGAB  \
# cid
# aab1-Primary solid Tumor   6.4    7.5  14.3    10.6   9.4  10.2    4.8   10.2
# aab4-Primary solid Tumor   5.8    6.8  14.0    10.2   9.1  10.3    6.3   10.4
# aab6-Primary solid Tumor   6.4    7.3  13.1    10.1   9.7   9.2    5.9    9.9
# aab8-Primary solid Tumor   5.8    7.5  13.8     8.6   9.6   9.4    6.4   10.5
# aab9-Primary solid Tumor   6.7    7.4  14.6    10.1   9.8   9.3    6.5   10.1
#
#                           AAK1  AAMP  ...  ZWILCH  ZWINT  ZXDA  ZXDB  ZXDC  \
# cid                                   ...
# aab1-Primary solid Tumor   9.6  11.8  ...     8.1    8.6   6.2   9.0   9.9
# aab4-Primary solid Tumor   9.8  11.4  ...     8.1    8.8   5.8   8.5  10.0
# aab6-Primary solid Tumor   9.8  11.1  ...     8.4    9.1   3.9   8.1  10.0
# aab8-Primary solid Tumor   9.2  11.6  ...     8.6    8.9   5.2   8.5   9.7
# aab9-Primary solid Tumor   9.8  11.2  ...     8.2    8.4   5.9   8.6   9.9
#
#                           ZYG11B   ZYX  ZZEF1  ZZZ3  \
# cid
# aab1-Primary solid Tumor     9.2  12.9   10.1   9.3
# aab4-Primary solid Tumor     9.3  12.4    9.8   8.9
# aab6-Primary solid Tumor     9.4  13.5    9.8   9.2
# aab8-Primary solid Tumor     9.4  12.5    9.7   9.3
# aab9-Primary solid Tumor     9.3  13.0   10.1   9.2
#
#                                 histological_type_other
# cid
# aab1-Primary solid Tumor        invasive adenocarcinoma
# aab4-Primary solid Tumor  invasive, well-differentiated
# aab6-Primary solid Tumor                            NaN
# aab8-Primary solid Tumor                            NaN
# aab9-Primary solid Tumor                            NaN
#
# [5 rows x 14099 columns]

# %%
target_names = df_new["histological_type_other"]
labels = list(set(target_names.tolist()))

# %%
user_colors = {}
sub_str = "neuroendocrine"
step_size = (256**3) // len(labels)
for i, user in enumerate(labels):
    if str(user).find(sub_str) == -1:
        user_colors[user] = "green"
    else:
        user_colors[user] = "red"
#print(user_colors)

# %%
colors_dict = [user_colors[user] for user in labels]
#print(colors_dict)
#cvec = [colors_dict[label] for label in labels]

# %% [markdown]
# ## PCA Plot with metadata column ‘histological_type_other’  (RED denotes Neuroendocrine)

# %%
fig = plt.figure()
fig,ax=plt.subplots(figsize=(25,10))
plt.scatter(principalComponents[:, 0], principalComponents[:, 1],
            edgecolor='none', alpha=0.5,s=100)
plt.xlabel('component 1')
plt.ylabel('component 2')
targets = labels

for target, color in zip(targets,colors_dict):
    #print(color)
    indicesToKeep = finalDf['target'] == target
    plt.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 100)
ax.legend(targets)

# %%
df_new.head()
# Out:
#                           A1BG  A2LD1   A2M  A4GALT  AAAS  AACS  AADAT  AAGAB  \
# cid
# aab1-Primary solid Tumor   6.4    7.5  14.3    10.6   9.4  10.2    4.8   10.2
# aab4-Primary solid Tumor   5.8    6.8  14.0    10.2   9.1  10.3    6.3   10.4
# aab6-Primary solid Tumor   6.4    7.3  13.1    10.1   9.7   9.2    5.9    9.9
# aab8-Primary solid Tumor   5.8    7.5  13.8     8.6   9.6   9.4    6.4   10.5
# aab9-Primary solid Tumor   6.7    7.4  14.6    10.1   9.8   9.3    6.5   10.1
#
#                           AAK1  AAMP  ...  ZWILCH  ZWINT  ZXDA  ZXDB  ZXDC  \
# cid                                   ...
# aab1-Primary solid Tumor   9.6  11.8  ...     8.1    8.6   6.2   9.0   9.9
# aab4-Primary solid Tumor   9.8  11.4  ...     8.1    8.8   5.8   8.5  10.0
# aab6-Primary solid Tumor   9.8  11.1  ...     8.4    9.1   3.9   8.1  10.0
# aab8-Primary solid Tumor   9.2  11.6  ...     8.6    8.9   5.2   8.5   9.7
# aab9-Primary solid Tumor   9.8  11.2  ...     8.2    8.4   5.9   8.6   9.9
#
#                           ZYG11B   ZYX  ZZEF1  ZZZ3  \
# cid
# aab1-Primary solid Tumor     9.2  12.9   10.1   9.3
# aab4-Primary solid Tumor     9.3  12.4    9.8   8.9
# aab6-Primary solid Tumor     9.4  13.5    9.8   9.2
# aab8-Primary solid Tumor     9.4  12.5    9.7   9.3
# aab9-Primary solid Tumor     9.3  13.0   10.1   9.2
#
#                                 histological_type_other
# cid
# aab1-Primary solid Tumor        invasive adenocarcinoma
# aab4-Primary solid Tumor  invasive, well-differentiated
# aab6-Primary solid Tumor                            NaN
# aab8-Primary solid Tumor                            NaN
# aab9-Primary solid Tumor                            NaN
#
# [5 rows x 14099 columns]

# %%
df_new = df_new.dropna()
df_new.head()
df_new.shape
# Out:
# (27, 14099)

# %%
adenocarcinoma_df = df_new.loc[df_new["histological_type_other"].str.contains("neuroendocrine")==False]

# %%
adenocarcinoma_df.shape
# Out:
# (18, 14099)

# %%
adenocarcinoma_df.head()
# Out:
#                           A1BG  A2LD1   A2M  A4GALT  AAAS  AACS  AADAT  AAGAB  \
# cid
# aab1-Primary solid Tumor   6.4    7.5  14.3    10.6   9.4  10.2    4.8   10.2
# aab4-Primary solid Tumor   5.8    6.8  14.0    10.2   9.1  10.3    6.3   10.4
# aabh-Primary solid Tumor   5.7    8.0  13.9     8.4   9.0   9.7    5.4    9.7
# aabi-Primary solid Tumor   6.3    5.8  11.9     7.9   9.3   9.1    4.1    9.8
# 6879-Primary solid Tumor   4.5    6.3  12.9     7.3   9.3  10.2    5.3    9.5
#
#                           AAK1  AAMP  ...  ZWILCH  ZWINT  ZXDA  ZXDB  ZXDC  \
# cid                                   ...
# aab1-Primary solid Tumor   9.6  11.8  ...     8.1    8.6   6.2   9.0   9.9
# aab4-Primary solid Tumor   9.8  11.4  ...     8.1    8.8   5.8   8.5  10.0
# aabh-Primary solid Tumor   9.7  11.8  ...     7.3    8.6   6.4   9.4   9.8
# aabi-Primary solid Tumor  10.5  12.0  ...     8.4    9.2   5.6   9.0  10.7
# 6879-Primary solid Tumor  10.0  11.6  ...     7.9    9.2   5.9   9.9   9.7
#
#                           ZYG11B   ZYX  ZZEF1  ZZZ3  \
# cid
# aab1-Primary solid Tumor     9.2  12.9   10.1   9.3
# aab4-Primary solid Tumor     9.3  12.4    9.8   8.9
# aabh-Primary solid Tumor     8.9  12.7   10.0   8.8
# aabi-Primary solid Tumor     8.3  12.5    9.9   8.6
# 6879-Primary solid Tumor     9.6  11.8   10.1   9.7
#
#                                        histological_type_other
# cid
# aab1-Primary solid Tumor               invasive adenocarcinoma
# aab4-Primary solid Tumor         invasive, well-differentiated
# aabh-Primary solid Tumor               invasive adenocarcinoma
# aabi-Primary solid Tumor  poorly differentiated adenocarcinoma
# 6879-Primary solid Tumor                   adenocarcinoma, nos
#
# [5 rows x 14099 columns]

# %%
from GSVA import gsva, gmt_to_dataframe
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-42969b4a7e44> in <module>
# ----> 1 from GSVA import gsva, gmt_to_dataframe
#
# C:\ProgramData\Anaconda3\lib\site-packages\GSVA\__init__.py in <module>
#      19
#      20 if which('Rscript') is None:
# ---> 21     raise ValueError("ERROR: Rscript command must be installed.  Install R")
#      22
#      23 def gsva(expression_df,geneset_df=None,
#
# ValueError: ERROR: Rscript command must be installed.  Install R

# %%
file1 = open("Copy of type1_IFN.txt","r")

# %%
geneset_data = file1.readlines()

# %%
len(geneset_data)
# Out:
# 25

# %%
gene_list = []
for data_gen in geneset_data:
    d = data_gen.split('\n')
    gene_list.append(d[0])

# %%
genesets_df = pd.DataFrame(gene_list)
genesets_df.columns = ["Genes"]
genesets_df.set_index('Genes')
genesets_df.head()
# Out:
#    Genes
# 0  IFIT1
# 1  IFI44
# 2  IFIT3
# 3    MX2
# 4   OAS1

# %%
expression_df=adenocarcinoma_df
expression_df.T.head()
# Out:
# cid    aab1-Primary solid Tumor aab4-Primary solid Tumor  \
# A1BG                        6.4                      5.8
# A2LD1                       7.5                      6.8
# A2M                        14.3                       14
# A4GALT                     10.6                     10.2
# AAAS                        9.4                      9.1
#
# cid    aabh-Primary solid Tumor aabi-Primary solid Tumor  \
# A1BG                        5.7                      6.3
# A2LD1                         8                      5.8
# A2M                        13.9                     11.9
# A4GALT                      8.4                      7.9
# AAAS                          9                      9.3
#
# cid    6879-Primary solid Tumor a45n-Solid Tissue Normal  \
# A1BG                        4.5                      7.2
# A2LD1                       6.3                      6.8
# A2M                        12.9                     13.6
# A4GALT                      7.3                      8.7
# AAAS                        9.3                       10
#
# cid    a45n-Primary solid Tumor a6c1-Primary solid Tumor  \
# A1BG                        7.1                      7.2
# A2LD1                       6.4                      6.7
# A2M                        14.5                     13.7
# A4GALT                        9                        9
# AAAS                        9.6                      8.9
#
# cid    a7op-Primary solid Tumor 7289-Primary solid Tumor  \
# A1BG                        5.9                      5.2
# A2LD1                       9.3                      6.3
# A2M                          12                     10.1
# A4GALT                      7.2                       10
# AAAS                          9                       10
#
# cid    8519-Primary solid Tumor a4bk-Primary solid Tumor  \
# A1BG                        7.9                      6.7
# A2LD1                       7.7                        6
# A2M                        14.7                       14
# A4GALT                      8.4                      9.5
# AAAS                        8.9                      9.8
#
# cid    a77p-Primary solid Tumor a77q-Primary solid Tumor a9tj-Metastatic  \
# A1BG                          6                      6.4             5.9
# A2LD1                       6.6                      6.8             7.5
# A2M                        14.6                     14.6            12.8
# A4GALT                      9.8                     10.7               8
# AAAS                        9.3                      8.9             9.3
#
# cid    a9tj-Primary solid Tumor a7b8-Primary solid Tumor  \
# A1BG                          6                      7.4
# A2LD1                       7.3                        7
# A2M                        13.8                     14.1
# A4GALT                      8.1                      8.3
# AAAS                        9.2                      9.6
#
# cid    a77e-Primary solid Tumor
# A1BG                        6.7
# A2LD1                       7.1
# A2M                        13.9
# A4GALT                       10
# AAAS                        9.2

# %%
new_df = gsva(expression_df,genesets_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-98-decdec462691> in <module>
# ----> 1 new_df = gsva(expression_df,genesets_df)
#
# NameError: name 'gsva' is not defined
